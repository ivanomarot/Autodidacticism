# %%
# %%writefile external_table.hql
#
# ADD JAR /opt/cloudera/parcels/CDH/lib/hive/lib/hive-contrib.jar;
# ADD JAR /opt/cloudera/parcels/CDH/lib/hive/lib/hive-serde.jar;
#
# USE mydb;
#
# set hive.exec.dynamic.partition=true;
# set hive.exec.dynamic.partition.mode=nonstrict;
# set hive.exec.max.dynamic.partitions=2000;
# set hive.exec.max.dynamic.partitions.pernode=1000;
# Out:
# Writing external_table.hql

# %%
# %%writefile -a external_table.hql
#
# DROP TABLE IF EXISTS mydb.posts_sample_external;
#
# CREATE EXTERNAL TABLE mydb.posts_sample_external (
#     `Id` INT,
#     `CreationDate` STRING,
#     `Year` STRING,
#     `Month` STRING
# )
# ROW FORMAT
#  SERDE 'org.apache.hadoop.hive.serde2.RegexSerDe'
#  WITH SERDEPROPERTIES(
#   "input.regex"='.*(?=.*\\bId\=\"(\\d+)\")(?=.*\\bCreationDate\=\"(\\d+\-\\d+\-\\d+T\\d+\:\\d+\:\\d+\.\\d+)\")(?=.*\\bCreationDate\=\"(\\d+)\-\\d+\-\\d+T\\d+\:\\d+\:\\d+\.\\d+\")(?=.*\\bCreationDate\=\"(\\d+\-\\d+)\-\\d+T\\d+\:\\d+\:\\d+\.\\d+\").*$'
#  )
# STORED AS TEXTFILE
# LOCATION '/data/stackexchange1000/posts';
# Out:
# Appending to external_table.hql

# %%
! hive -f external_table.hql
# Out:
# Logging initialized using configuration in jar:file:/usr/local/apache-hive-1.1.0-bin/lib/hive-common-1.1.0.jar!/hive-log4j.properties
# Added [/opt/cloudera/parcels/CDH/lib/hive/lib/hive-contrib.jar] to class path
# Added resources: [/opt/cloudera/parcels/CDH/lib/hive/lib/hive-contrib.jar]
# Added [/opt/cloudera/parcels/CDH/lib/hive/lib/hive-serde.jar] to class path
# Added resources: [/opt/cloudera/parcels/CDH/lib/hive/lib/hive-serde.jar]
# OK
# Time taken: 1.079 seconds
# OK
# Time taken: 0.127 seconds
# OK
# Time taken: 0.831 seconds

# %%
# %%writefile query.hql
#
# ADD JAR /opt/cloudera/parcels/CDH/lib/hive/lib/hive-contrib.jar;
# USE mydb;
#
# SELECT Id, CreationDate, Year, Month
# FROM mydb.posts_sample_external
# LIMIT 10;
# Out:
# Writing query.hql

# %%
! hive -f query.hql
# Out:
# Logging initialized using configuration in jar:file:/usr/local/apache-hive-1.1.0-bin/lib/hive-common-1.1.0.jar!/hive-log4j.properties
# Added [/opt/cloudera/parcels/CDH/lib/hive/lib/hive-contrib.jar] to class path
# Added resources: [/opt/cloudera/parcels/CDH/lib/hive/lib/hive-contrib.jar]
# OK
# Time taken: 1.067 seconds
# OK
# NULL	NULL	NULL	NULL
# 1394	2008-08-04T16:38:03.667	2008	2008-08
# 3543	2008-08-06T15:24:00.787	2008	2008-08
# 4521	2008-08-07T08:22:27.440	2008	2008-08
# 8689	2008-08-12T11:23:28.733	2008	2008-08
# 9062	2008-08-12T17:20:41.993	2008	2008-08
# 14671	2008-08-18T14:18:22.310	2008	2008-08
# 16307	2008-08-19T14:45:07.997	2008	2008-08
# 18780	2008-08-20T20:44:27.947	2008	2008-08
# 18929	2008-08-20T21:49:23.203	2008	2008-08
# Time taken: 1.869 seconds, Fetched: 10 row(s)

# %%
# %%writefile managed_table.hql
#
# ADD JAR /opt/cloudera/parcels/CDH/lib/hive/lib/hive-contrib.jar;
# ADD JAR /opt/cloudera/parcels/CDH/lib/hive/lib/hive-serde.jar;
#
# USE mydb;
#
# set hive.exec.dynamic.partition=true;
# set hive.exec.dynamic.partition.mode=nonstrict;
# set hive.exec.max.dynamic.partitions=2000;
# set hive.exec.max.dynamic.partitions.pernode=1000;
# Out:
# Writing managed_table.hql

# %%
# %%writefile -a managed_table.hql
#
# DROP TABLE IF EXISTS mydb.posts_sample;
#
# CREATE TABLE mydb.posts_sample (
#     `Id` INT,
#     `CreationDate` STRING
# )
# PARTITIONED BY (`Year` STRING,`Month` STRING);
#
# INSERT OVERWRITE TABLE mydb.posts_sample PARTITION(`Year`,`Month`)
# SELECT `Id`,`CreationDate`,`Year`,`Month` FROM mydb.posts_sample_external;
# Out:
# Appending to managed_table.hql

# %%
! hive -f managed_table.hql
# Out:
# Logging initialized using configuration in jar:file:/usr/local/apache-hive-1.1.0-bin/lib/hive-common-1.1.0.jar!/hive-log4j.properties
# Added [/opt/cloudera/parcels/CDH/lib/hive/lib/hive-contrib.jar] to class path
# Added resources: [/opt/cloudera/parcels/CDH/lib/hive/lib/hive-contrib.jar]
# Added [/opt/cloudera/parcels/CDH/lib/hive/lib/hive-serde.jar] to class path
# Added resources: [/opt/cloudera/parcels/CDH/lib/hive/lib/hive-serde.jar]
# OK
# Time taken: 1.088 seconds
# OK
# Time taken: 0.114 seconds
# OK
# Time taken: 0.968 seconds
# Query ID = jovyan_20180310150808_6ecf5959-0e83-424d-b145-d07c7f31fb9f
# Total jobs = 3
# Launching Job 1 out of 3
# Number of reduce tasks is set to 0 since there's no reduce operator
# Starting Job = job_1520685033293_0004, Tracking URL = http://526a7513a472:8088/proxy/application_1520685033293_0004/
# Kill Command = /opt/hadoop/bin/hadoop job  -kill job_1520685033293_0004
# Hadoop job information for Stage-1: number of mappers: 1; number of reducers: 0
# 2018-03-10 15:09:11,123 Stage-1 map = 0%,  reduce = 0%
# 2018-03-10 15:09:42,401 Stage-1 map = 1%,  reduce = 0%, Cumulative CPU 25.95 sec
# 2018-03-10 15:10:41,828 Stage-1 map = 2%,  reduce = 0%, Cumulative CPU 86.39 sec
# 2018-03-10 15:11:12,416 Stage-1 map = 3%,  reduce = 0%, Cumulative CPU 116.6 sec
# 2018-03-10 15:11:48,297 Stage-1 map = 4%,  reduce = 0%, Cumulative CPU 152.79 sec
# 2018-03-10 15:12:41,977 Stage-1 map = 5%,  reduce = 0%, Cumulative CPU 207.03 sec
# 2018-03-10 15:13:18,775 Stage-1 map = 6%,  reduce = 0%, Cumulative CPU 243.36 sec
# 2018-03-10 15:14:06,109 Stage-1 map = 7%,  reduce = 0%, Cumulative CPU 291.78 sec
# 2018-03-10 15:15:06,936 Stage-1 map = 8%,  reduce = 0%, Cumulative CPU 351.99 sec
# 2018-03-10 15:16:00,447 Stage-1 map = 9%,  reduce = 0%, Cumulative CPU 406.24 sec
# 2018-03-10 15:16:54,947 Stage-1 map = 10%,  reduce = 0%, Cumulative CPU 460.47 sec
# 2018-03-10 15:17:43,185 Stage-1 map = 11%,  reduce = 0%, Cumulative CPU 508.73 sec
# 2018-03-10 15:18:43,938 Stage-1 map = 11%,  reduce = 0%, Cumulative CPU 569.08 sec
# 2018-03-10 15:18:49,177 Stage-1 map = 12%,  reduce = 0%, Cumulative CPU 575.1 sec
# 2018-03-10 15:19:31,094 Stage-1 map = 13%,  reduce = 0%, Cumulative CPU 617.26 sec
# 2018-03-10 15:20:19,252 Stage-1 map = 14%,  reduce = 0%, Cumulative CPU 665.95 sec
# 2018-03-10 15:21:19,852 Stage-1 map = 14%,  reduce = 0%, Cumulative CPU 726.15 sec
# 2018-03-10 15:21:31,342 Stage-1 map = 15%,  reduce = 0%, Cumulative CPU 738.2 sec
# 2018-03-10 15:22:31,858 Stage-1 map = 15%,  reduce = 0%, Cumulative CPU 798.6 sec
# 2018-03-10 15:22:43,328 Stage-1 map = 16%,  reduce = 0%, Cumulative CPU 810.65 sec
# 2018-03-10 15:23:25,074 Stage-1 map = 17%,  reduce = 0%, Cumulative CPU 852.88 sec
# 2018-03-10 15:24:01,594 Stage-1 map = 18%,  reduce = 0%, Cumulative CPU 889.02 sec
# 2018-03-10 15:24:49,618 Stage-1 map = 19%,  reduce = 0%, Cumulative CPU 937.18 sec
# 2018-03-10 15:25:37,599 Stage-1 map = 20%,  reduce = 0%, Cumulative CPU 985.34 sec
# 2018-03-10 15:26:38,076 Stage-1 map = 21%,  reduce = 0%, Cumulative CPU 1045.54 sec
# 2018-03-10 15:27:26,076 Stage-1 map = 22%,  reduce = 0%, Cumulative CPU 1093.81 sec
# 2018-03-10 15:28:26,526 Stage-1 map = 22%,  reduce = 0%, Cumulative CPU 1154.02 sec
# 2018-03-10 15:28:55,706 Stage-1 map = 23%,  reduce = 0%, Cumulative CPU 1184.16 sec
# 2018-03-10 15:29:56,044 Stage-1 map = 23%,  reduce = 0%, Cumulative CPU 1232.31 sec
# 2018-03-10 15:30:02,290 Stage-1 map = 24%,  reduce = 0%, Cumulative CPU 1250.37 sec
# 2018-03-10 15:31:02,701 Stage-1 map = 24%,  reduce = 0%, Cumulative CPU 1310.65 sec
# 2018-03-10 15:31:07,904 Stage-1 map = 25%,  reduce = 0%, Cumulative CPU 1316.69 sec
# 2018-03-10 15:31:55,806 Stage-1 map = 26%,  reduce = 0%, Cumulative CPU 1364.84 sec
# 2018-03-10 15:32:38,483 Stage-1 map = 27%,  reduce = 0%, Cumulative CPU 1407.33 sec
# 2018-03-10 15:33:38,828 Stage-1 map = 27%,  reduce = 0%, Cumulative CPU 1467.68 sec
# 2018-03-10 15:34:26,648 Stage-1 map = 28%,  reduce = 0%, Cumulative CPU 1516.01 sec
# 2018-03-10 15:35:20,764 Stage-1 map = 29%,  reduce = 0%, Cumulative CPU 1570.39 sec
# 2018-03-10 15:36:20,026 Stage-1 map = 30%,  reduce = 0%, Cumulative CPU 1624.71 sec
# 2018-03-10 15:37:20,318 Stage-1 map = 31%,  reduce = 0%, Cumulative CPU 1691.85 sec
# 2018-03-10 15:38:20,603 Stage-1 map = 32%,  reduce = 0%, Cumulative CPU 1752.2 sec
# 2018-03-10 15:39:20,907 Stage-1 map = 33%,  reduce = 0%, Cumulative CPU 1812.41 sec
# 2018-03-10 15:40:02,515 Stage-1 map = 34%,  reduce = 0%, Cumulative CPU 1854.59 sec
# 2018-03-10 15:41:02,863 Stage-1 map = 34%,  reduce = 0%, Cumulative CPU 1914.83 sec
# 2018-03-10 15:41:33,013 Stage-1 map = 35%,  reduce = 0%, Cumulative CPU 1945.05 sec
# 2018-03-10 15:42:33,329 Stage-1 map = 35%,  reduce = 0%, Cumulative CPU 2005.33 sec
# 2018-03-10 15:42:44,787 Stage-1 map = 36%,  reduce = 0%, Cumulative CPU 2017.04 sec
# 2018-03-10 15:43:45,050 Stage-1 map = 37%,  reduce = 0%, Cumulative CPU 2077.27 sec
# 2018-03-10 15:44:45,333 Stage-1 map = 37%,  reduce = 0%, Cumulative CPU 2137.57 sec
# 2018-03-10 15:45:21,726 Stage-1 map = 38%,  reduce = 0%, Cumulative CPU 2173.68 sec
# 2018-03-10 15:46:22,002 Stage-1 map = 38%,  reduce = 0%, Cumulative CPU 2234.01 sec
# 2018-03-10 15:46:27,209 Stage-1 map = 39%,  reduce = 0%, Cumulative CPU 2240.02 sec
# 2018-03-10 15:47:27,483 Stage-1 map = 40%,  reduce = 0%, Cumulative CPU 2300.31 sec
# 2018-03-10 15:48:27,776 Stage-1 map = 41%,  reduce = 0%, Cumulative CPU 2360.57 sec
# 2018-03-10 15:49:28,093 Stage-1 map = 41%,  reduce = 0%, Cumulative CPU 2420.82 sec
# 2018-03-10 15:49:51,995 Stage-1 map = 42%,  reduce = 0%, Cumulative CPU 2444.93 sec
# 2018-03-10 15:50:52,243 Stage-1 map = 42%,  reduce = 0%, Cumulative CPU 2505.2 sec
# 2018-03-10 15:51:45,252 Stage-1 map = 43%,  reduce = 0%, Cumulative CPU 2559.39 sec
# 2018-03-10 15:52:34,101 Stage-1 map = 44%,  reduce = 0%, Cumulative CPU 2607.59 sec
# 2018-03-10 15:53:21,892 Stage-1 map = 45%,  reduce = 0%, Cumulative CPU 2655.77 sec
# 2018-03-10 15:54:22,186 Stage-1 map = 45%,  reduce = 0%, Cumulative CPU 2716.04 sec
# 2018-03-10 15:54:28,415 Stage-1 map = 46%,  reduce = 0%, Cumulative CPU 2722.02 sec
# 2018-03-10 15:55:27,661 Stage-1 map = 47%,  reduce = 0%, Cumulative CPU 2782.4 sec
# 2018-03-10 15:56:21,712 Stage-1 map = 48%,  reduce = 0%, Cumulative CPU 2836.55 sec
# 2018-03-10 15:57:21,984 Stage-1 map = 49%,  reduce = 0%, Cumulative CPU 2896.78 sec
# 2018-03-10 15:58:22,278 Stage-1 map = 49%,  reduce = 0%, Cumulative CPU 2957.01 sec
# 2018-03-10 15:58:39,935 Stage-1 map = 50%,  reduce = 0%, Cumulative CPU 2975.08 sec
# 2018-03-10 15:59:40,211 Stage-1 map = 50%,  reduce = 0%, Cumulative CPU 3035.33 sec
# 2018-03-10 16:00:04,098 Stage-1 map = 51%,  reduce = 0%, Cumulative CPU 3059.47 sec
# 2018-03-10 16:01:04,446 Stage-1 map = 52%,  reduce = 0%, Cumulative CPU 3119.73 sec
# 2018-03-10 16:02:04,695 Stage-1 map = 52%,  reduce = 0%, Cumulative CPU 3179.98 sec
# 2018-03-10 16:02:10,934 Stage-1 map = 53%,  reduce = 0%, Cumulative CPU 3185.99 sec
# 2018-03-10 16:03:11,137 Stage-1 map = 53%,  reduce = 0%, Cumulative CPU 3246.18 sec
# 2018-03-10 16:03:35,018 Stage-1 map = 54%,  reduce = 0%, Cumulative CPU 3270.27 sec
# 2018-03-10 16:04:35,227 Stage-1 map = 54%,  reduce = 0%, Cumulative CPU 3330.56 sec
# 2018-03-10 16:04:52,860 Stage-1 map = 55%,  reduce = 0%, Cumulative CPU 3348.64 sec
# 2018-03-10 16:05:53,056 Stage-1 map = 56%,  reduce = 0%, Cumulative CPU 3409.71 sec
# 2018-03-10 16:06:53,252 Stage-1 map = 56%,  reduce = 0%, Cumulative CPU 3469.96 sec
# 2018-03-10 16:07:04,673 Stage-1 map = 57%,  reduce = 0%, Cumulative CPU 3482.03 sec
# 2018-03-10 16:08:04,875 Stage-1 map = 57%,  reduce = 0%, Cumulative CPU 3542.25 sec
# 2018-03-10 16:08:28,756 Stage-1 map = 58%,  reduce = 0%, Cumulative CPU 3566.33 sec
# 2018-03-10 16:09:28,958 Stage-1 map = 59%,  reduce = 0%, Cumulative CPU 3626.58 sec
# 2018-03-10 16:10:29,167 Stage-1 map = 60%,  reduce = 0%, Cumulative CPU 3686.79 sec
# 2018-03-10 16:11:23,145 Stage-1 map = 61%,  reduce = 0%, Cumulative CPU 3741.16 sec
# 2018-03-10 16:12:23,370 Stage-1 map = 61%,  reduce = 0%, Cumulative CPU 3801.39 sec
# 2018-03-10 16:12:34,797 Stage-1 map = 62%,  reduce = 0%, Cumulative CPU 3813.41 sec
# 2018-03-10 16:13:34,997 Stage-1 map = 62%,  reduce = 0%, Cumulative CPU 3873.66 sec
# 2018-03-10 16:13:47,455 Stage-1 map = 63%,  reduce = 0%, Cumulative CPU 3885.69 sec
# 2018-03-10 16:14:47,668 Stage-1 map = 64%,  reduce = 0%, Cumulative CPU 3945.93 sec
# 2018-03-10 16:15:47,843 Stage-1 map = 64%,  reduce = 0%, Cumulative CPU 3988.08 sec
# 2018-03-10 16:16:41,809 Stage-1 map = 65%,  reduce = 0%, Cumulative CPU 4060.29 sec
# 2018-03-10 16:17:41,997 Stage-1 map = 65%,  reduce = 0%, Cumulative CPU 4108.54 sec
# 2018-03-10 16:17:53,427 Stage-1 map = 66%,  reduce = 0%, Cumulative CPU 4132.65 sec
# 2018-03-10 16:18:53,615 Stage-1 map = 67%,  reduce = 0%, Cumulative CPU 4192.89 sec
# 2018-03-10 16:19:53,784 Stage-1 map = 67%,  reduce = 0%, Cumulative CPU 4253.11 sec
# 2018-03-10 16:20:05,195 Stage-1 map = 68%,  reduce = 0%, Cumulative CPU 4265.13 sec
# 2018-03-10 16:21:05,541 Stage-1 map = 68%,  reduce = 0%, Cumulative CPU 4325.39 sec
# 2018-03-10 16:21:29,427 Stage-1 map = 69%,  reduce = 0%, Cumulative CPU 4349.46 sec
# 2018-03-10 16:22:29,603 Stage-1 map = 70%,  reduce = 0%, Cumulative CPU 4409.72 sec
# 2018-03-10 16:23:29,830 Stage-1 map = 70%,  reduce = 0%, Cumulative CPU 4469.93 sec
# 2018-03-10 16:24:06,155 Stage-1 map = 71%,  reduce = 0%, Cumulative CPU 4506.12 sec
# 2018-03-10 16:25:06,346 Stage-1 map = 71%,  reduce = 0%, Cumulative CPU 4554.33 sec
# 2018-03-10 16:25:54,112 Stage-1 map = 72%,  reduce = 0%, Cumulative CPU 4614.56 sec
# 2018-03-10 16:26:54,306 Stage-1 map = 72%,  reduce = 0%, Cumulative CPU 4674.8 sec
# 2018-03-10 16:27:24,384 Stage-1 map = 73%,  reduce = 0%, Cumulative CPU 4704.91 sec
# 2018-03-10 16:28:24,557 Stage-1 map = 74%,  reduce = 0%, Cumulative CPU 4765.12 sec
# 2018-03-10 16:29:24,748 Stage-1 map = 74%,  reduce = 0%, Cumulative CPU 4825.35 sec
# 2018-03-10 16:29:42,385 Stage-1 map = 75%,  reduce = 0%, Cumulative CPU 4843.39 sec
# 2018-03-10 16:30:43,189 Stage-1 map = 75%,  reduce = 0%, Cumulative CPU 4867.47 sec
# 2018-03-10 16:31:43,851 Stage-1 map = 75%,  reduce = 0%, Cumulative CPU 4962.69 sec
# 2018-03-10 16:31:54,223 Stage-1 map = 76%,  reduce = 0%, Cumulative CPU 4974.75 sec
# 2018-03-10 16:32:54,420 Stage-1 map = 77%,  reduce = 0%, Cumulative CPU 5034.99 sec
# 2018-03-10 16:33:54,621 Stage-1 map = 77%,  reduce = 0%, Cumulative CPU 5089.23 sec
# 2018-03-10 16:34:36,142 Stage-1 map = 78%,  reduce = 0%, Cumulative CPU 5137.41 sec
# 2018-03-10 16:35:36,386 Stage-1 map = 78%,  reduce = 0%, Cumulative CPU 5197.67 sec
# 2018-03-10 16:36:00,249 Stage-1 map = 79%,  reduce = 0%, Cumulative CPU 5221.77 sec
# 2018-03-10 16:37:00,486 Stage-1 map = 79%,  reduce = 0%, Cumulative CPU 5276.02 sec
# 2018-03-10 16:37:12,929 Stage-1 map = 80%,  reduce = 0%, Cumulative CPU 5294.07 sec
# 2018-03-10 16:38:13,117 Stage-1 map = 80%,  reduce = 0%, Cumulative CPU 5354.76 sec
# 2018-03-10 16:38:24,546 Stage-1 map = 81%,  reduce = 0%, Cumulative CPU 5366.79 sec
# 2018-03-10 16:39:24,754 Stage-1 map = 81%,  reduce = 0%, Cumulative CPU 5427.07 sec
# 2018-03-10 16:39:54,855 Stage-1 map = 82%,  reduce = 0%, Cumulative CPU 5457.16 sec
# 2018-03-10 16:40:55,030 Stage-1 map = 82%,  reduce = 0%, Cumulative CPU 5517.42 sec
# 2018-03-10 16:41:18,911 Stage-1 map = 83%,  reduce = 0%, Cumulative CPU 5541.5 sec
# 2018-03-10 16:42:19,143 Stage-1 map = 83%,  reduce = 0%, Cumulative CPU 5601.77 sec
# 2018-03-10 16:42:25,423 Stage-1 map = 84%,  reduce = 0%, Cumulative CPU 5607.8 sec
# 2018-03-10 16:43:19,410 Stage-1 map = 85%,  reduce = 0%, Cumulative CPU 5663.36 sec
# 2018-03-10 16:44:19,578 Stage-1 map = 85%,  reduce = 0%, Cumulative CPU 5723.66 sec
# 2018-03-10 16:44:24,771 Stage-1 map = 86%,  reduce = 0%, Cumulative CPU 5729.67 sec
# 2018-03-10 16:45:24,987 Stage-1 map = 86%,  reduce = 0%, Cumulative CPU 5789.96 sec
# 2018-03-10 16:45:37,436 Stage-1 map = 87%,  reduce = 0%, Cumulative CPU 5802.05 sec
# 2018-03-10 16:46:37,644 Stage-1 map = 87%,  reduce = 0%, Cumulative CPU 5862.29 sec
# 2018-03-10 16:46:42,832 Stage-1 map = 88%,  reduce = 0%, Cumulative CPU 5868.34 sec
# 2018-03-10 16:47:43,041 Stage-1 map = 88%,  reduce = 0%, Cumulative CPU 5928.58 sec
# 2018-03-10 16:48:37,000 Stage-1 map = 89%,  reduce = 0%, Cumulative CPU 5982.84 sec
# 2018-03-10 16:49:37,172 Stage-1 map = 89%,  reduce = 0%, Cumulative CPU 6043.07 sec
# 2018-03-10 16:49:49,614 Stage-1 map = 90%,  reduce = 0%, Cumulative CPU 6055.11 sec
# 2018-03-10 16:50:49,925 Stage-1 map = 90%,  reduce = 0%, Cumulative CPU 6103.33 sec
# 2018-03-10 16:51:43,878 Stage-1 map = 91%,  reduce = 0%, Cumulative CPU 6169.58 sec
# 2018-03-10 16:52:37,962 Stage-1 map = 92%,  reduce = 0%, Cumulative CPU 6223.82 sec
# 2018-03-10 16:53:38,197 Stage-1 map = 92%,  reduce = 0%, Cumulative CPU 6284.09 sec
# 2018-03-10 16:53:55,832 Stage-1 map = 93%,  reduce = 0%, Cumulative CPU 6302.14 sec
# 2018-03-10 16:54:56,042 Stage-1 map = 93%,  reduce = 0%, Cumulative CPU 6356.39 sec
# 2018-03-10 16:55:56,223 Stage-1 map = 93%,  reduce = 0%, Cumulative CPU 6404.57 sec
# 2018-03-10 16:56:13,848 Stage-1 map = 94%,  reduce = 0%, Cumulative CPU 6440.67 sec
# 2018-03-10 16:57:13,988 Stage-1 map = 94%,  reduce = 0%, Cumulative CPU 6501.03 sec
# 2018-03-10 16:57:31,621 Stage-1 map = 95%,  reduce = 0%, Cumulative CPU 6519.1 sec
# 2018-03-10 16:58:31,761 Stage-1 map = 95%,  reduce = 0%, Cumulative CPU 6579.33 sec
# 2018-03-10 16:58:55,612 Stage-1 map = 96%,  reduce = 0%, Cumulative CPU 6603.57 sec
# 2018-03-10 16:59:55,788 Stage-1 map = 96%,  reduce = 0%, Cumulative CPU 6651.8 sec
# 2018-03-10 17:00:55,876 Stage-1 map = 97%,  reduce = 0%, Cumulative CPU 6722.83 sec
# 2018-03-10 17:01:56,018 Stage-1 map = 97%,  reduce = 0%, Cumulative CPU 6782.08 sec
# 2018-03-10 17:02:02,292 Stage-1 map = 98%,  reduce = 0%, Cumulative CPU 6788.01 sec
# 2018-03-10 17:03:02,932 Stage-1 map = 98%,  reduce = 0%, Cumulative CPU 6847.38 sec
# 2018-03-10 17:03:08,196 Stage-1 map = 99%,  reduce = 0%, Cumulative CPU 6853.33 sec
# 2018-03-10 17:04:08,881 Stage-1 map = 99%,  reduce = 0%, Cumulative CPU 6912.83 sec
# 2018-03-10 17:04:44,362 Stage-1 map = 100%,  reduce = 0%, Cumulative CPU 6948.73 sec
# MapReduce Total cumulative CPU time: 0 days 1 hours 55 minutes 48 seconds 730 msec
# Ended Job = job_1520685033293_0004
# Stage-4 is selected by condition resolver.
# Stage-3 is filtered out by condition resolver.
# Stage-5 is filtered out by condition resolver.
# Moving data to: hdfs://localhost:9000/user/jovyan/somemetastore/posts_sample/.hive-staging_hive_2018-03-10_15-08-55_217_2407282347931343828-1/-ext-10000
# Loading data to table mydb.posts_sample partition (year=null, month=null)
# 	 Time taken for load dynamic partitions : 14567
# 	Loading partition {year=2011, month=2011-08}
# 	Loading partition {year=2012, month=2012-01}
# 	Loading partition {year=2011, month=2011-11}
# 	Loading partition {year=2012, month=2012-07}
# 	Loading partition {year=2010, month=2010-12}
# 	Loading partition {year=2011, month=2011-02}
# 	Loading partition {year=2013, month=2013-06}
# 	Loading partition {year=2010, month=2010-03}
# 	Loading partition {year=2009, month=2009-04}
# 	Loading partition {year=2016, month=2016-04}
# 	Loading partition {year=2014, month=2014-05}
# 	Loading partition {year=2009, month=2009-03}
# 	Loading partition {year=2016, month=2016-03}
# 	Loading partition {year=2010, month=2010-08}
# 	Loading partition {year=2013, month=2013-01}
# 	Loading partition {year=2011, month=2011-07}
# 	Loading partition {year=2015, month=2015-04}
# 	Loading partition {year=2012, month=2012-02}
# 	Loading partition {year=2011, month=2011-03}
# 	Loading partition {year=2012, month=2012-06}
# 	Loading partition {year=2010, month=2010-04}
# 	Loading partition {year=2013, month=2013-05}
# 	Loading partition {year=2010, month=2010-09}
# 	Loading partition {year=2015, month=2015-03}
# 	Loading partition {year=2008, month=2008-09}
# 	Loading partition {year=2015, month=2015-09}
# 	Loading partition {year=2015, month=2015-06}
# 	Loading partition {year=2014, month=2014-01}
# 	Loading partition {year=2010, month=2010-07}
# 	Loading partition {year=2013, month=2013-11}
# 	Loading partition {year=2012, month=2012-03}
# 	Loading partition {year=2010, month=2010-11}
# 	Loading partition {year=2012, month=2012-05}
# 	Loading partition {year=2012, month=2012-08}
# 	Loading partition {year=2012, month=2012-11}
# 	Loading partition {year=2010, month=2010-02}
# 	Loading partition {year=2010, month=2010-05}
# 	Loading partition {year=2016, month=2016-12}
# 	Loading partition {year=2009, month=2009-12}
# 	Loading partition {year=2009, month=2009-09}
# 	Loading partition {year=2016, month=2016-09}
# 	Loading partition {year=2014, month=2014-06}
# 	Loading partition {year=2015, month=2015-01}
# 	Loading partition {year=__HIVE_DEFAULT_PARTITION__, month=__HIVE_DEFAULT_PARTITION__}
# 	Loading partition {year=2013, month=2013-03}
# 	Loading partition {year=2013, month=2013-08}
# 	Loading partition {year=2011, month=2011-05}
# 	Loading partition {year=2008, month=2008-12}
# 	Loading partition {year=2015, month=2015-12}
# 	Loading partition {year=2009, month=2009-10}
# 	Loading partition {year=2013, month=2013-09}
# 	Loading partition {year=2016, month=2016-10}
# 	Loading partition {year=2009, month=2009-01}
# 	Loading partition {year=2016, month=2016-01}
# 	Loading partition {year=2014, month=2014-12}
# 	Loading partition {year=2015, month=2015-02}
# 	Loading partition {year=2008, month=2008-11}
# 	Loading partition {year=2015, month=2015-11}
# 	Loading partition {year=2014, month=2014-08}
# 	Loading partition {year=2015, month=2015-07}
# 	Loading partition {year=2016, month=2016-06}
# 	Loading partition {year=2014, month=2014-03}
# 	Loading partition {year=2009, month=2009-06}
# 	Loading partition {year=2014, month=2014-11}
# 	Loading partition {year=2008, month=2008-08}
# 	Loading partition {year=2008, month=2008-10}
# 	Loading partition {year=2015, month=2015-08}
# 	Loading partition {year=2015, month=2015-10}
# 	Loading partition {year=2014, month=2014-09}
# 	Loading partition {year=2013, month=2013-12}
# 	Loading partition {year=2009, month=2009-07}
# 	Loading partition {year=2016, month=2016-07}
# 	Loading partition {year=2010, month=2010-10}
# 	Loading partition {year=2009, month=2009-02}
# 	Loading partition {year=2016, month=2016-02}
# 	Loading partition {year=2014, month=2014-10}
# 	Loading partition {year=2014, month=2014-04}
# 	Loading partition {year=2009, month=2009-05}
# 	Loading partition {year=2016, month=2016-05}
# 	Loading partition {year=2009, month=2009-08}
# 	Loading partition {year=2016, month=2016-08}
# 	Loading partition {year=2013, month=2013-02}
# 	Loading partition {year=2012, month=2012-12}
# 	Loading partition {year=2011, month=2011-10}
# 	Loading partition {year=2011, month=2011-06}
# 	Loading partition {year=2011, month=2011-01}
# 	Loading partition {year=2011, month=2011-04}
# 	Loading partition {year=2011, month=2011-09}
# 	Loading partition {year=2013, month=2013-07}
# 	Loading partition {year=2013, month=2013-04}
# 	Loading partition {year=2013, month=2013-10}
# 	Loading partition {year=2011, month=2011-12}
# 	Loading partition {year=2015, month=2015-05}
# 	Loading partition {year=2014, month=2014-02}
# 	Loading partition {year=2009, month=2009-11}
# 	Loading partition {year=2016, month=2016-11}
# 	Loading partition {year=2010, month=2010-01}
# 	Loading partition {year=2012, month=2012-09}
# 	Loading partition {year=2010, month=2010-06}
# 	Loading partition {year=2012, month=2012-04}
# 	Loading partition {year=2012, month=2012-10}
# 	Loading partition {year=2014, month=2014-07}
# 	 Time taken for adding to write entity : 32
# Partition mydb.posts_sample{year=2008, month=2008-08} stats: [numFiles=1, numRows=23, totalSize=685, rawDataSize=662]
# Partition mydb.posts_sample{year=2008, month=2008-09} stats: [numFiles=1, numRows=89, totalSize=2708, rawDataSize=2619]
# Partition mydb.posts_sample{year=2008, month=2008-10} stats: [numFiles=1, numRows=73, totalSize=2263, rawDataSize=2190]
# Partition mydb.posts_sample{year=2008, month=2008-11} stats: [numFiles=1, numRows=54, totalSize=1674, rawDataSize=1620]
# Partition mydb.posts_sample{year=2008, month=2008-12} stats: [numFiles=1, numRows=51, totalSize=1581, rawDataSize=1530]
# Partition mydb.posts_sample{year=2009, month=2009-01} stats: [numFiles=1, numRows=84, totalSize=2604, rawDataSize=2520]
# Partition mydb.posts_sample{year=2009, month=2009-02} stats: [numFiles=1, numRows=84, totalSize=2604, rawDataSize=2520]
# Partition mydb.posts_sample{year=2009, month=2009-03} stats: [numFiles=1, numRows=85, totalSize=2635, rawDataSize=2550]
# Partition mydb.posts_sample{year=2009, month=2009-04} stats: [numFiles=1, numRows=97, totalSize=3007, rawDataSize=2910]
# Partition mydb.posts_sample{year=2009, month=2009-05} stats: [numFiles=1, numRows=111, totalSize=3441, rawDataSize=3330]
# Partition mydb.posts_sample{year=2009, month=2009-06} stats: [numFiles=1, numRows=120, totalSize=3788, rawDataSize=3668]
# Partition mydb.posts_sample{year=2009, month=2009-07} stats: [numFiles=1, numRows=133, totalSize=4256, rawDataSize=4123]
# Partition mydb.posts_sample{year=2009, month=2009-08} stats: [numFiles=1, numRows=129, totalSize=4128, rawDataSize=3999]
# Partition mydb.posts_sample{year=2009, month=2009-09} stats: [numFiles=1, numRows=128, totalSize=4096, rawDataSize=3968]
# Partition mydb.posts_sample{year=2009, month=2009-10} stats: [numFiles=1, numRows=133, totalSize=4256, rawDataSize=4123]
# Partition mydb.posts_sample{year=2009, month=2009-11} stats: [numFiles=1, numRows=149, totalSize=4768, rawDataSize=4619]
# Partition mydb.posts_sample{year=2009, month=2009-12} stats: [numFiles=1, numRows=147, totalSize=4704, rawDataSize=4557]
# Partition mydb.posts_sample{year=2010, month=2010-01} stats: [numFiles=1, numRows=175, totalSize=5600, rawDataSize=5425]
# Partition mydb.posts_sample{year=2010, month=2010-02} stats: [numFiles=1, numRows=162, totalSize=5184, rawDataSize=5022]
# Partition mydb.posts_sample{year=2010, month=2010-03} stats: [numFiles=1, numRows=190, totalSize=6080, rawDataSize=5890]
# Partition mydb.posts_sample{year=2010, month=2010-04} stats: [numFiles=1, numRows=179, totalSize=5728, rawDataSize=5549]
# Partition mydb.posts_sample{year=2010, month=2010-05} stats: [numFiles=1, numRows=168, totalSize=5376, rawDataSize=5208]
# Partition mydb.posts_sample{year=2010, month=2010-06} stats: [numFiles=1, numRows=201, totalSize=6432, rawDataSize=6231]
# Partition mydb.posts_sample{year=2010, month=2010-07} stats: [numFiles=1, numRows=209, totalSize=6688, rawDataSize=6479]
# Partition mydb.posts_sample{year=2010, month=2010-08} stats: [numFiles=1, numRows=212, totalSize=6784, rawDataSize=6572]
# Partition mydb.posts_sample{year=2010, month=2010-09} stats: [numFiles=1, numRows=208, totalSize=6656, rawDataSize=6448]
# Partition mydb.posts_sample{year=2010, month=2010-10} stats: [numFiles=1, numRows=222, totalSize=7104, rawDataSize=6882]
# Partition mydb.posts_sample{year=2010, month=2010-11} stats: [numFiles=1, numRows=236, totalSize=7552, rawDataSize=7316]
# Partition mydb.posts_sample{year=2010, month=2010-12} stats: [numFiles=1, numRows=237, totalSize=7584, rawDataSize=7347]
# Partition mydb.posts_sample{year=2011, month=2011-01} stats: [numFiles=1, numRows=276, totalSize=8832, rawDataSize=8556]
# Partition mydb.posts_sample{year=2011, month=2011-02} stats: [numFiles=1, numRows=273, totalSize=8736, rawDataSize=8463]
# Partition mydb.posts_sample{year=2011, month=2011-03} stats: [numFiles=1, numRows=349, totalSize=11168, rawDataSize=10819]
# Partition mydb.posts_sample{year=2011, month=2011-04} stats: [numFiles=1, numRows=321, totalSize=10272, rawDataSize=9951]
# Partition mydb.posts_sample{year=2011, month=2011-05} stats: [numFiles=1, numRows=327, totalSize=10464, rawDataSize=10137]
# Partition mydb.posts_sample{year=2011, month=2011-06} stats: [numFiles=1, numRows=340, totalSize=10880, rawDataSize=10540]
# Partition mydb.posts_sample{year=2011, month=2011-07} stats: [numFiles=1, numRows=335, totalSize=10720, rawDataSize=10385]
# Partition mydb.posts_sample{year=2011, month=2011-08} stats: [numFiles=1, numRows=362, totalSize=11584, rawDataSize=11222]
# Partition mydb.posts_sample{year=2011, month=2011-09} stats: [numFiles=1, numRows=343, totalSize=10976, rawDataSize=10633]
# Partition mydb.posts_sample{year=2011, month=2011-10} stats: [numFiles=1, numRows=331, totalSize=10592, rawDataSize=10261]
# Partition mydb.posts_sample{year=2011, month=2011-11} stats: [numFiles=1, numRows=361, totalSize=11552, rawDataSize=11191]
# Partition mydb.posts_sample{year=2011, month=2011-12} stats: [numFiles=1, numRows=350, totalSize=11200, rawDataSize=10850]
# Partition mydb.posts_sample{year=2012, month=2012-01} stats: [numFiles=1, numRows=377, totalSize=12064, rawDataSize=11687]
# Partition mydb.posts_sample{year=2012, month=2012-02} stats: [numFiles=1, numRows=412, totalSize=13184, rawDataSize=12772]
# Partition mydb.posts_sample{year=2012, month=2012-03} stats: [numFiles=1, numRows=432, totalSize=13824, rawDataSize=13392]
# Partition mydb.posts_sample{year=2012, month=2012-04} stats: [numFiles=1, numRows=412, totalSize=13560, rawDataSize=13148]
# Partition mydb.posts_sample{year=2012, month=2012-05} stats: [numFiles=1, numRows=429, totalSize=14157, rawDataSize=13728]
# Partition mydb.posts_sample{year=2012, month=2012-06} stats: [numFiles=1, numRows=412, totalSize=13596, rawDataSize=13184]
# Partition mydb.posts_sample{year=2012, month=2012-07} stats: [numFiles=1, numRows=445, totalSize=14685, rawDataSize=14240]
# Partition mydb.posts_sample{year=2012, month=2012-08} stats: [numFiles=1, numRows=445, totalSize=14685, rawDataSize=14240]
# Partition mydb.posts_sample{year=2012, month=2012-09} stats: [numFiles=1, numRows=399, totalSize=13167, rawDataSize=12768]
# Partition mydb.posts_sample{year=2012, month=2012-10} stats: [numFiles=1, numRows=469, totalSize=15477, rawDataSize=15008]
# Partition mydb.posts_sample{year=2012, month=2012-11} stats: [numFiles=1, numRows=438, totalSize=14454, rawDataSize=14016]
# Partition mydb.posts_sample{year=2012, month=2012-12} stats: [numFiles=1, numRows=415, totalSize=13695, rawDataSize=13280]
# Partition mydb.posts_sample{year=2013, month=2013-01} stats: [numFiles=1, numRows=484, totalSize=15972, rawDataSize=15488]
# Partition mydb.posts_sample{year=2013, month=2013-02} stats: [numFiles=1, numRows=474, totalSize=15642, rawDataSize=15168]
# Partition mydb.posts_sample{year=2013, month=2013-03} stats: [numFiles=1, numRows=533, totalSize=17589, rawDataSize=17056]
# Partition mydb.posts_sample{year=2013, month=2013-04} stats: [numFiles=1, numRows=529, totalSize=17457, rawDataSize=16928]
# Partition mydb.posts_sample{year=2013, month=2013-05} stats: [numFiles=1, numRows=520, totalSize=17160, rawDataSize=16640]
# Partition mydb.posts_sample{year=2013, month=2013-06} stats: [numFiles=1, numRows=477, totalSize=15741, rawDataSize=15264]
# Partition mydb.posts_sample{year=2013, month=2013-07} stats: [numFiles=1, numRows=550, totalSize=18150, rawDataSize=17600]
# Partition mydb.posts_sample{year=2013, month=2013-08} stats: [numFiles=1, numRows=531, totalSize=17523, rawDataSize=16992]
# Partition mydb.posts_sample{year=2013, month=2013-09} stats: [numFiles=1, numRows=511, totalSize=16863, rawDataSize=16352]
# Partition mydb.posts_sample{year=2013, month=2013-10} stats: [numFiles=1, numRows=570, totalSize=18810, rawDataSize=18240]
# Partition mydb.posts_sample{year=2013, month=2013-11} stats: [numFiles=1, numRows=543, totalSize=17919, rawDataSize=17376]
# Partition mydb.posts_sample{year=2013, month=2013-12} stats: [numFiles=1, numRows=513, totalSize=16929, rawDataSize=16416]
# Partition mydb.posts_sample{year=2014, month=2014-01} stats: [numFiles=1, numRows=595, totalSize=19635, rawDataSize=19040]
# Partition mydb.posts_sample{year=2014, month=2014-02} stats: [numFiles=1, numRows=585, totalSize=19305, rawDataSize=18720]
# Partition mydb.posts_sample{year=2014, month=2014-03} stats: [numFiles=1, numRows=624, totalSize=20592, rawDataSize=19968]
# Partition mydb.posts_sample{year=2014, month=2014-04} stats: [numFiles=1, numRows=593, totalSize=19569, rawDataSize=18976]
# Partition mydb.posts_sample{year=2014, month=2014-05} stats: [numFiles=1, numRows=541, totalSize=17853, rawDataSize=17312]
# Partition mydb.posts_sample{year=2014, month=2014-06} stats: [numFiles=1, numRows=487, totalSize=16071, rawDataSize=15584]
# Partition mydb.posts_sample{year=2014, month=2014-07} stats: [numFiles=1, numRows=536, totalSize=17688, rawDataSize=17152]
# Partition mydb.posts_sample{year=2014, month=2014-08} stats: [numFiles=1, numRows=495, totalSize=16335, rawDataSize=15840]
# Partition mydb.posts_sample{year=2014, month=2014-09} stats: [numFiles=1, numRows=502, totalSize=16566, rawDataSize=16064]
# Partition mydb.posts_sample{year=2014, month=2014-10} stats: [numFiles=1, numRows=527, totalSize=17391, rawDataSize=16864]
# Partition mydb.posts_sample{year=2014, month=2014-11} stats: [numFiles=1, numRows=501, totalSize=16533, rawDataSize=16032]
# Partition mydb.posts_sample{year=2014, month=2014-12} stats: [numFiles=1, numRows=482, totalSize=15906, rawDataSize=15424]
# Partition mydb.posts_sample{year=2015, month=2015-01} stats: [numFiles=1, numRows=502, totalSize=16566, rawDataSize=16064]
# Partition mydb.posts_sample{year=2015, month=2015-02} stats: [numFiles=1, numRows=506, totalSize=16698, rawDataSize=16192]
# Partition mydb.posts_sample{year=2015, month=2015-03} stats: [numFiles=1, numRows=568, totalSize=18744, rawDataSize=18176]
# Partition mydb.posts_sample{year=2015, month=2015-04} stats: [numFiles=1, numRows=581, totalSize=19173, rawDataSize=18592]
# Partition mydb.posts_sample{year=2015, month=2015-05} stats: [numFiles=1, numRows=566, totalSize=18678, rawDataSize=18112]
# Partition mydb.posts_sample{year=2015, month=2015-06} stats: [numFiles=1, numRows=570, totalSize=18810, rawDataSize=18240]
# Partition mydb.posts_sample{year=2015, month=2015-07} stats: [numFiles=1, numRows=585, totalSize=19305, rawDataSize=18720]
# Partition mydb.posts_sample{year=2015, month=2015-08} stats: [numFiles=1, numRows=554, totalSize=18282, rawDataSize=17728]
# Partition mydb.posts_sample{year=2015, month=2015-09} stats: [numFiles=1, numRows=536, totalSize=17688, rawDataSize=17152]
# Partition mydb.posts_sample{year=2015, month=2015-10} stats: [numFiles=1, numRows=561, totalSize=18513, rawDataSize=17952]
# Partition mydb.posts_sample{year=2015, month=2015-11} stats: [numFiles=1, numRows=529, totalSize=17457, rawDataSize=16928]
# Partition mydb.posts_sample{year=2015, month=2015-12} stats: [numFiles=1, numRows=537, totalSize=17721, rawDataSize=17184]
# Partition mydb.posts_sample{year=2016, month=2016-01} stats: [numFiles=1, numRows=582, totalSize=19206, rawDataSize=18624]
# Partition mydb.posts_sample{year=2016, month=2016-02} stats: [numFiles=1, numRows=592, totalSize=19536, rawDataSize=18944]
# Partition mydb.posts_sample{year=2016, month=2016-03} stats: [numFiles=1, numRows=638, totalSize=21054, rawDataSize=20416]
# Partition mydb.posts_sample{year=2016, month=2016-04} stats: [numFiles=1, numRows=619, totalSize=20427, rawDataSize=19808]
# Partition mydb.posts_sample{year=2016, month=2016-05} stats: [numFiles=1, numRows=603, totalSize=19899, rawDataSize=19296]
# Partition mydb.posts_sample{year=2016, month=2016-06} stats: [numFiles=1, numRows=584, totalSize=19272, rawDataSize=18688]
# Partition mydb.posts_sample{year=2016, month=2016-07} stats: [numFiles=1, numRows=562, totalSize=18546, rawDataSize=17984]
# Partition mydb.posts_sample{year=2016, month=2016-08} stats: [numFiles=1, numRows=571, totalSize=18843, rawDataSize=18272]
# Partition mydb.posts_sample{year=2016, month=2016-09} stats: [numFiles=1, numRows=545, totalSize=17985, rawDataSize=17440]
# Partition mydb.posts_sample{year=2016, month=2016-10} stats: [numFiles=1, numRows=554, totalSize=18282, rawDataSize=17728]
# Partition mydb.posts_sample{year=2016, month=2016-11} stats: [numFiles=1, numRows=562, totalSize=18546, rawDataSize=17984]
# Partition mydb.posts_sample{year=2016, month=2016-12} stats: [numFiles=1, numRows=195, totalSize=6435, rawDataSize=6240]
# Partition mydb.posts_sample{year=__HIVE_DEFAULT_PARTITION__, month=__HIVE_DEFAULT_PARTITION__} stats: [numFiles=1, numRows=384, totalSize=2304, rawDataSize=1920]
# MapReduce Jobs Launched:
# Stage-Stage-1: Map: 1   Cumulative CPU: 6950.43 sec   HDFS Read: 60003379 HDFS Write: 1287223 SUCCESS
# Total MapReduce CPU Time Spent: 0 days 1 hours 55 minutes 50 seconds 430 msec
# OK
# Time taken: 6982.496 seconds

# %%
# %%writefile last_query.hql
#
# ADD JAR /opt/cloudera/parcels/CDH/lib/hive/lib/hive-contrib.jar;
# USE mydb;
#
# WITH T AS (
# SELECT Year, Month, COUNT(Id) AS TotalId, RANK() OVER(ORDER BY Month) AS RowNumber
# FROM mydb.posts_sample
# GROUP BY Year, Month
# )
# SELECT Year,Month, TotalId FROM T WHERE RowNumber=3
# Out:
# Overwriting last_query.hql

# %%
! hive -f last_query.hql
# Out:
# Logging initialized using configuration in jar:file:/usr/local/apache-hive-1.1.0-bin/lib/hive-common-1.1.0.jar!/hive-log4j.properties
# Added [/opt/cloudera/parcels/CDH/lib/hive/lib/hive-contrib.jar] to class path
# Added resources: [/opt/cloudera/parcels/CDH/lib/hive/lib/hive-contrib.jar]
# OK
# Time taken: 1.056 seconds
# Query ID = jovyan_20180310174949_d9cce322-79a1-487e-9851-031c9e03a056
# Total jobs = 2
# Launching Job 1 out of 2
# Number of reduce tasks not specified. Estimated from input data size: 1
# In order to change the average load for a reducer (in bytes):
#   set hive.exec.reducers.bytes.per.reducer=<number>
# In order to limit the maximum number of reducers:
#   set hive.exec.reducers.max=<number>
# In order to set a constant number of reducers:
#   set mapreduce.job.reduces=<number>
# Starting Job = job_1520685033293_0014, Tracking URL = http://526a7513a472:8088/proxy/application_1520685033293_0014/
# Kill Command = /opt/hadoop/bin/hadoop job  -kill job_1520685033293_0014
# Hadoop job information for Stage-1: number of mappers: 1; number of reducers: 1
# 2018-03-10 17:49:18,759 Stage-1 map = 0%,  reduce = 0%
# 2018-03-10 17:49:28,503 Stage-1 map = 100%,  reduce = 0%, Cumulative CPU 7.17 sec
# 2018-03-10 17:49:37,181 Stage-1 map = 100%,  reduce = 100%, Cumulative CPU 10.76 sec
# MapReduce Total cumulative CPU time: 10 seconds 760 msec
# Ended Job = job_1520685033293_0014
# Launching Job 2 out of 2
# Number of reduce tasks not specified. Estimated from input data size: 1
# In order to change the average load for a reducer (in bytes):
#   set hive.exec.reducers.bytes.per.reducer=<number>
# In order to limit the maximum number of reducers:
#   set hive.exec.reducers.max=<number>
# In order to set a constant number of reducers:
#   set mapreduce.job.reduces=<number>
# Starting Job = job_1520685033293_0015, Tracking URL = http://526a7513a472:8088/proxy/application_1520685033293_0015/
# Kill Command = /opt/hadoop/bin/hadoop job  -kill job_1520685033293_0015
# Hadoop job information for Stage-2: number of mappers: 1; number of reducers: 1
# 2018-03-10 17:49:54,931 Stage-2 map = 0%,  reduce = 0%
# 2018-03-10 17:50:03,571 Stage-2 map = 100%,  reduce = 0%, Cumulative CPU 3.34 sec
# 2018-03-10 17:50:13,292 Stage-2 map = 100%,  reduce = 100%, Cumulative CPU 8.77 sec
# MapReduce Total cumulative CPU time: 8 seconds 770 msec
# Ended Job = job_1520685033293_0015
# MapReduce Jobs Launched:
# Stage-Stage-1: Map: 1  Reduce: 1   Cumulative CPU: 10.76 sec   HDFS Read: 1330350 HDFS Write: 3480 SUCCESS
# Stage-Stage-2: Map: 1  Reduce: 1   Cumulative CPU: 8.77 sec   HDFS Read: 10535 HDFS Write: 16 SUCCESS
# Total MapReduce CPU Time Spent: 19 seconds 530 msec
# OK
# 2008	2008-10	73
# Time taken: 73.956 seconds, Fetched: 1 row(s)
