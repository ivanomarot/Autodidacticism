# %%
# %%writefile mapper.py

import sys
import re

reload(sys)
sys.setdefaultencoding('utf-8') # required to convert to unicode

for line in sys.stdin:
    try:
        article_id, text = unicode(line.strip()).split('\t', 1)
    except ValueError as e:
        continue
    words = re.split("\W*\s+\W*", text, flags=re.UNICODE)
    for word in words:
        print >> sys.stderr, "reporter:counter:Wiki stats,Total words,%d" % 1
        print "%s\t%d" % (word.lower(), 1)
# Out:
# Writing mapper.py

# %%
# %%writefile reducer.py

import sys

current_key = None
word_sum = 0

for line in sys.stdin:
    try:
        key, count = line.strip().split('\t', 1)
        count = int(count)
    except ValueError as e:
        continue
    if current_key != key:
        if current_key:
            print "%s\t%d" % (current_key, word_sum)
        word_sum = 0
        current_key = key
    word_sum += count

if current_key:
    print "%s\t%d" % (current_key, word_sum)
# Out:
# Writing reducer.py

# %%
# %%writefile mapper2.py

import sys
import re

reload(sys)
sys.setdefaultencoding('utf-8') # required to convert to unicode

for line in sys.stdin:
    try:
        key, count = unicode(line.strip()).split('\t', 1)
        count = int(count)
    except ValueError as e:
        continue
    words = re.split("\W*\s+\W*", key, flags=re.UNICODE)
    for word in words:
        print >> sys.stderr, "reporter:counter:Wiki stats,Total words,%d" % 1
        print "%s\t%d" % (word.lower(), count)
# Out:
# Writing mapper2.py

# %%
# %%writefile reducer2.py

import sys

current_key = None
word_sum = 0
stop_sum=0
list_index=0
percentage=0.0

with open("stop_words_en.txt") as stopfile:
    #stopwords = [line.rstrip() for line in stopfile]
    stopwords = stopfile.readlines()

for line in sys.stdin:
    try:
        key, count = line.strip().split('\t', 1)
        count = int(count)
    except ValueError as e:
        continue
    word_sum += count
    for stopword in stopwords:
        #list_index += 1
        #print("%s\t%s" % (stopword.strip(), key))
        if stopword.strip() == key:
            stop_sum += count
            #del stopwords[list_index]
            #break
#print "Words: %d" % word_sum
#print "Stop Words: %d" % stop_sum
word_sum = float(word_sum)
stop_sum = float(stop_sum)
percentage = ( stop_sum / word_sum ) * 100.0
print "%f" % percentage
# Out:
# Overwriting reducer2.py

# %%
# %%bash
#
# OUT_DIR="wordcount_result_"$(date +"%s%6N")
# NUM_REDUCERS=8
#
# hdfs dfs -rm -r -skipTrash ${OUT_DIR} > /dev/null
#
# yarn jar /opt/cloudera/parcels/CDH/lib/hadoop-mapreduce/hadoop-streaming.jar \
#     -D mapred.jab.name="Streaming Stop Words1" \
#     -D mapreduce.job.reduces=${NUM_REDUCERS} \
#     -files mapper.py,reducer.py \
#     -mapper "python mapper.py" \
#     -combiner "python reducer.py" \
#     -reducer "python reducer.py" \
#     -input /data/wiki/en_articles_part \
#     -output ${OUT_DIR} > /dev/null
#
# #hdfs dfs -cat ${OUT_DIR}/part-00000 | head
#
# OUT_DIR2="wordcount_result_"$(date +"%s%6N")
# NUM_REDUCERS2=1
#
# hdfs dfs -rm -r -skipTrash ${OUT_DIR2} > /dev/null
#
# yarn jar /opt/cloudera/parcels/CDH/lib/hadoop-mapreduce/hadoop-streaming.jar \
#     -D mapred.jab.name="Streaming Stop Words2" \
#     -D mapreduce.job.reduces=${NUM_REDUCERS2} \
#     -files mapper2.py,reducer2.py,/datasets/stop_words_en.txt \
#     -mapper "python2 mapper2.py" \
#     -reducer "python2 reducer2.py" \
#     -input ${OUT_DIR} \
#     -output ${OUT_DIR2} > /dev/null
#
# hdfs dfs -cat ${OUT_DIR2}/part-00000
# Out:
# 41.602824
# rm: `wordcount_result_1513078572194714': No such file or directory
# 17/12/12 11:36:15 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 17/12/12 11:36:15 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 17/12/12 11:36:17 INFO mapred.FileInputFormat: Total input files to process : 1
# 17/12/12 11:36:17 INFO mapreduce.JobSubmitter: number of splits:2
# 17/12/12 11:36:17 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_1513013126012_0003
# 17/12/12 11:36:17 INFO impl.YarnClientImpl: Submitted application application_1513013126012_0003
# 17/12/12 11:36:17 INFO mapreduce.Job: The url to track the job: http://4b76fe1cdd03:8088/proxy/application_1513013126012_0003/
# 17/12/12 11:36:17 INFO mapreduce.Job: Running job: job_1513013126012_0003
# 17/12/12 11:36:23 INFO mapreduce.Job: Job job_1513013126012_0003 running in uber mode : false
# 17/12/12 11:36:23 INFO mapreduce.Job:  map 0% reduce 0%
# 17/12/12 11:36:40 INFO mapreduce.Job:  map 30% reduce 0%
# 17/12/12 11:36:46 INFO mapreduce.Job:  map 45% reduce 0%
# 17/12/12 11:36:52 INFO mapreduce.Job:  map 47% reduce 0%
# 17/12/12 11:36:58 INFO mapreduce.Job:  map 62% reduce 0%
# 17/12/12 11:37:04 INFO mapreduce.Job:  map 67% reduce 0%
# 17/12/12 11:37:06 INFO mapreduce.Job:  map 100% reduce 0%
# 17/12/12 11:37:11 INFO mapreduce.Job:  map 100% reduce 13%
# 17/12/12 11:37:12 INFO mapreduce.Job:  map 100% reduce 25%
# 17/12/12 11:37:13 INFO mapreduce.Job:  map 100% reduce 38%
# 17/12/12 11:37:14 INFO mapreduce.Job:  map 100% reduce 50%
# 17/12/12 11:37:15 INFO mapreduce.Job:  map 100% reduce 63%
# 17/12/12 11:37:16 INFO mapreduce.Job:  map 100% reduce 75%
# 17/12/12 11:37:17 INFO mapreduce.Job:  map 100% reduce 100%
# 17/12/12 11:37:18 INFO mapreduce.Job: Job job_1513013126012_0003 completed successfully
# 17/12/12 11:37:18 INFO mapreduce.Job: Counters: 51
# 	File System Counters
# 		FILE: Number of bytes read=17954826
# 		FILE: Number of bytes written=28258083
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=76874501
# 		HDFS: Number of bytes written=5370513
# 		HDFS: Number of read operations=30
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of write operations=16
# 	Job Counters
# 		Killed reduce tasks=1
# 		Launched map tasks=2
# 		Launched reduce tasks=8
# 		Data-local map tasks=2
# 		Total time spent by all maps in occupied slots (ms)=79792
# 		Total time spent by all reduces in occupied slots (ms)=22405
# 		Total time spent by all map tasks (ms)=79792
# 		Total time spent by all reduce tasks (ms)=22405
# 		Total vcore-milliseconds taken by all map tasks=79792
# 		Total vcore-milliseconds taken by all reduce tasks=22405
# 		Total megabyte-milliseconds taken by all map tasks=81707008
# 		Total megabyte-milliseconds taken by all reduce tasks=22942720
# 	Map-Reduce Framework
# 		Map input records=4100
# 		Map output records=11937375
# 		Map output bytes=97842436
# 		Map output materialized bytes=8952763
# 		Input split bytes=228
# 		Combine input records=11937375
# 		Combine output records=640011
# 		Reduce input groups=427175
# 		Reduce shuffle bytes=8952763
# 		Reduce input records=640011
# 		Reduce output records=427175
# 		Spilled Records=1920033
# 		Shuffled Maps =16
# 		Failed Shuffles=0
# 		Merged Map outputs=16
# 		GC time elapsed (ms)=1331
# 		CPU time spent (ms)=147440
# 		Physical memory (bytes) snapshot=2399150080
# 		Virtual memory (bytes) snapshot=20219453440
# 		Total committed heap usage (bytes)=1601175552
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	Wiki stats
# 		Total words=11937375
# 	File Input Format Counters
# 		Bytes Read=76874273
# 	File Output Format Counters
# 		Bytes Written=5370513
# 17/12/12 11:37:18 INFO streaming.StreamJob: Output directory: wordcount_result_1513078572194714
# rm: `wordcount_result_1513078638680019': No such file or directory
# 17/12/12 11:37:22 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 17/12/12 11:37:22 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 17/12/12 11:37:22 INFO mapred.FileInputFormat: Total input files to process : 8
# 17/12/12 11:37:23 INFO mapreduce.JobSubmitter: number of splits:8
# 17/12/12 11:37:23 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_1513013126012_0004
# 17/12/12 11:37:23 INFO impl.YarnClientImpl: Submitted application application_1513013126012_0004
# 17/12/12 11:37:24 INFO mapreduce.Job: The url to track the job: http://4b76fe1cdd03:8088/proxy/application_1513013126012_0004/
# 17/12/12 11:37:24 INFO mapreduce.Job: Running job: job_1513013126012_0004
# 17/12/12 11:37:30 INFO mapreduce.Job: Job job_1513013126012_0004 running in uber mode : false
# 17/12/12 11:37:30 INFO mapreduce.Job:  map 0% reduce 0%
# 17/12/12 11:37:36 INFO mapreduce.Job:  map 75% reduce 0%
# 17/12/12 11:37:40 INFO mapreduce.Job:  map 100% reduce 0%
# 17/12/12 11:37:53 INFO mapreduce.Job:  map 100% reduce 81%
# 17/12/12 11:37:59 INFO mapreduce.Job:  map 100% reduce 89%
# 17/12/12 11:38:05 INFO mapreduce.Job:  map 100% reduce 97%
# 17/12/12 11:38:08 INFO mapreduce.Job:  map 100% reduce 100%
# 17/12/12 11:38:09 INFO mapreduce.Job: Job job_1513013126012_0004 completed successfully
# 17/12/12 11:38:09 INFO mapreduce.Job: Counters: 50
# 	File System Counters
# 		FILE: Number of bytes read=6224888
# 		FILE: Number of bytes written=13709799
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=5371553
# 		HDFS: Number of bytes written=11
# 		HDFS: Number of read operations=27
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of write operations=2
# 	Job Counters
# 		Launched map tasks=8
# 		Launched reduce tasks=1
# 		Data-local map tasks=8
# 		Total time spent by all maps in occupied slots (ms)=31986
# 		Total time spent by all reduces in occupied slots (ms)=29391
# 		Total time spent by all map tasks (ms)=31986
# 		Total time spent by all reduce tasks (ms)=29391
# 		Total vcore-milliseconds taken by all map tasks=31986
# 		Total vcore-milliseconds taken by all reduce tasks=29391
# 		Total megabyte-milliseconds taken by all map tasks=32753664
# 		Total megabyte-milliseconds taken by all reduce tasks=30096384
# 	Map-Reduce Framework
# 		Map input records=427175
# 		Map output records=427175
# 		Map output bytes=5370522
# 		Map output materialized bytes=6224930
# 		Input split bytes=1040
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=427175
# 		Reduce shuffle bytes=6224930
# 		Reduce input records=427175
# 		Reduce output records=1
# 		Spilled Records=854350
# 		Shuffled Maps =8
# 		Failed Shuffles=0
# 		Merged Map outputs=8
# 		GC time elapsed (ms)=1084
# 		CPU time spent (ms)=49120
# 		Physical memory (bytes) snapshot=2610225152
# 		Virtual memory (bytes) snapshot=18107957248
# 		Total committed heap usage (bytes)=1703936000
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	Wiki stats
# 		Total words=427175
# 	File Input Format Counters
# 		Bytes Read=5370513
# 	File Output Format Counters
# 		Bytes Written=11
# 17/12/12 11:38:09 INFO streaming.StreamJob: Output directory: wordcount_result_1513078638680019
