# %%
# %%writefile mapper.py

import sys
import re

reload(sys)
sys.setdefaultencoding('utf-8') # required to convert to unicode

for line in sys.stdin:
    try:
        article_id, text = unicode(line.strip()).split('\t', 1)
    except ValueError as e:
        continue
    words = re.split("\W*\s+\W*", text, flags=re.UNICODE)
    for word in words:
        print "%s\t%d" % (word, 1)
# Out:
# Overwriting mapper.py

# %%
# %%writefile reducer.py

import sys

current_key = None
word_sum = 0
stop_sum=0
list_index=0
word_count=0
stop_count=0
percentage=0.0

with open("stop_words_en.txt") as stopfile:
    stopwords = stopfile.readlines()

for line in sys.stdin:
    try:
        key, count = line.strip().split('\t', 1)
        count = int(count)
    except ValueError as e:
        continue
    if current_key != key:
        if current_key:
            print "%s\t%d" % (current_key, word_sum)
            for stopword in stopwords:
                if stopword.strip() == current_key:
                    stop_sum += word_sum
                    print >> sys.stderr, "reporter:counter:Wiki stats,Total stop words,%d" % stop_sum
                    stop_count += stop_sum
            print >> sys.stderr, "reporter:counter:Wiki stats,Total words,%d" % word_sum
            word_count += word_sum
        word_sum = 0
        stop_sum = 0
        current_key = key
    word_sum += count
if current_key:
    print "%s\t%d" % (current_key, word_sum)
    for stopword in stopwords:
        if stopword.strip() == current_key:
            stop_sum += word_sum
            print >> sys.stderr, "reporter:counter:Wiki stats,Stop words,%d" % stop_sum
            stop_count += stop_sum
    print >> sys.stderr, "reporter:counter:Wiki stats,Total words,%d" % word_sum
    word_count += word_sum
word_count = float(word_count)
stop_count = float(stop_count)
percentage = ( stop_count / word_count ) * 100.0
#print "%f" % percentage
# Out:
# Overwriting reducer.py

# %%
# %%writefile mapper2.py

import sys
import re

reload(sys)
sys.setdefaultencoding('utf-8') # required to convert to unicode

for line in sys.stdin:
    try:
        key, count = unicode(line.strip()).split('\t', 1)
        count = int(count)
    except ValueError as e:
        continue
    words = re.split("\W*\s+\W*", key, flags=re.UNICODE)
    for word in words:
        print "%s\t%d" % (word, count)
# Out:
# Overwriting mapper2.py

# %%
# %%writefile reducer2.py

import sys

current_key = None
word_sum = 0
stop_sum=0
list_index=0
percentage=0.0

with open("stop_words_en.txt") as stopfile:
    #stopwords = [line.rstrip() for line in stopfile]
    stopwords = stopfile.readlines()

for line in sys.stdin:
    try:
        key, count = line.strip().split('\t', 1)
        count = int(count)
    except ValueError as e:
        continue
    word_sum += count
    for stopword in stopwords:
        #list_index += 1
        #print("%s\t%s" % (stopword.strip(), key))
        if stopword.strip() == key:
            stop_sum += count
            #del stopwords[list_index]
            #break
#print "Words: %d" % word_sum
#print "Stop Words: %d" % stop_sum
word_sum = float(word_sum)
stop_sum = float(stop_sum)
percentage = ( stop_sum / word_sum ) * 100.0
print "%f" % percentage
# Out:
# Overwriting reducer2.py

# %%
# %%bash
#
# OUT_DIR="wordcount_result_"$(date +"%s%6N")
# NUM_REDUCERS=8
#
# hdfs dfs -rm -r -skipTrash ${OUT_DIR} > /dev/null
#
# yarn jar /opt/cloudera/parcels/CDH/lib/hadoop-mapreduce/hadoop-streaming.jar \
#     -D mapred.jab.name="Streaming Stop Words1" \
#     -D mapreduce.job.reduces=${NUM_REDUCERS} \
#     -files mapper.py,reducer.py,/datasets/stop_words_en.txt \
#     -mapper "python2 mapper.py" \
#     -reducer "python2 reducer.py" \
#     -input /data/wiki/en_articles_part \
#     -output ${OUT_DIR} > /dev/null
#
# #hdfs dfs -cat ${OUT_DIR}/part-00000 | head
#
# OUT_DIR2="wordcount_result_"$(date +"%s%6N")
# NUM_REDUCERS2=1
#
# hdfs dfs -rm -r -skipTrash ${OUT_DIR2} > /dev/null
#
# yarn jar /opt/cloudera/parcels/CDH/lib/hadoop-mapreduce/hadoop-streaming.jar \
#     -D mapred.jab.name="Streaming Stop Words2" \
#     -D mapreduce.job.reduces=${NUM_REDUCERS2} \
#     -files mapper2.py,reducer2.py,/datasets/stop_words_en.txt \
#     -mapper "python2 mapper2.py" \
#     -reducer "python2 reducer2.py" \
#     -input ${OUT_DIR} \
#     -output ${OUT_DIR2} > /dev/null
#
# hdfs dfs -cat ${OUT_DIR2}/part-00000
# Out:
# 38.440556
# rm: `wordcount_result_1513158834763286': No such file or directory
# 17/12/13 09:53:58 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 17/12/13 09:53:58 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 17/12/13 09:53:58 INFO mapred.FileInputFormat: Total input files to process : 1
# 17/12/13 09:53:59 INFO mapreduce.JobSubmitter: number of splits:2
# 17/12/13 09:53:59 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_1513144645380_0012
# 17/12/13 09:53:59 INFO impl.YarnClientImpl: Submitted application application_1513144645380_0012
# 17/12/13 09:53:59 INFO mapreduce.Job: The url to track the job: http://8466be51a335:8088/proxy/application_1513144645380_0012/
# 17/12/13 09:53:59 INFO mapreduce.Job: Running job: job_1513144645380_0012
# 17/12/13 09:54:05 INFO mapreduce.Job: Job job_1513144645380_0012 running in uber mode : false
# 17/12/13 09:54:05 INFO mapreduce.Job:  map 0% reduce 0%
# 17/12/13 09:54:21 INFO mapreduce.Job:  map 46% reduce 0%
# 17/12/13 09:54:27 INFO mapreduce.Job:  map 67% reduce 0%
# 17/12/13 09:54:32 INFO mapreduce.Job:  map 83% reduce 0%
# 17/12/13 09:54:33 INFO mapreduce.Job:  map 98% reduce 0%
# 17/12/13 09:54:34 INFO mapreduce.Job:  map 100% reduce 0%
# 17/12/13 09:54:46 INFO mapreduce.Job:  map 100% reduce 13%
# 17/12/13 09:54:47 INFO mapreduce.Job:  map 100% reduce 25%
# 17/12/13 09:54:49 INFO mapreduce.Job:  map 100% reduce 49%
# 17/12/13 09:54:50 INFO mapreduce.Job:  map 100% reduce 74%
# 17/12/13 09:54:51 INFO mapreduce.Job:  map 100% reduce 75%
# 17/12/13 09:54:58 INFO mapreduce.Job:  map 100% reduce 100%
# 17/12/13 09:54:58 INFO mapreduce.Job: Job job_1513144645380_0012 completed successfully
# 17/12/13 09:54:58 INFO mapreduce.Job: Counters: 52
# 	File System Counters
# 		FILE: Number of bytes read=243471452
# 		FILE: Number of bytes written=366551828
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=76874501
# 		HDFS: Number of bytes written=5884946
# 		HDFS: Number of read operations=30
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of write operations=16
# 	Job Counters
# 		Killed reduce tasks=1
# 		Launched map tasks=2
# 		Launched reduce tasks=9
# 		Data-local map tasks=2
# 		Total time spent by all maps in occupied slots (ms)=52106
# 		Total time spent by all reduces in occupied slots (ms)=95811
# 		Total time spent by all map tasks (ms)=52106
# 		Total time spent by all reduce tasks (ms)=95811
# 		Total vcore-milliseconds taken by all map tasks=52106
# 		Total vcore-milliseconds taken by all reduce tasks=95811
# 		Total megabyte-milliseconds taken by all map tasks=53356544
# 		Total megabyte-milliseconds taken by all reduce tasks=98110464
# 	Map-Reduce Framework
# 		Map input records=4100
# 		Map output records=11937375
# 		Map output bytes=97842522
# 		Map output materialized bytes=121717378
# 		Input split bytes=228
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=474355
# 		Reduce shuffle bytes=121717378
# 		Reduce input records=11937375
# 		Reduce output records=474354
# 		Spilled Records=35812125
# 		Shuffled Maps =16
# 		Failed Shuffles=0
# 		Merged Map outputs=16
# 		GC time elapsed (ms)=1497
# 		CPU time spent (ms)=117930
# 		Physical memory (bytes) snapshot=2308018176
# 		Virtual memory (bytes) snapshot=20202782720
# 		Total committed heap usage (bytes)=1573388288
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	Wiki stats
# 		Total stop words=4588771
# 		Total words=11937317
# 	File Input Format Counters
# 		Bytes Read=76874273
# 	File Output Format Counters
# 		Bytes Written=5884946
# 17/12/13 09:54:58 INFO streaming.StreamJob: Output directory: wordcount_result_1513158834763286
# rm: `wordcount_result_1513158899132688': No such file or directory
# 17/12/13 09:55:02 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 17/12/13 09:55:02 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 17/12/13 09:55:03 INFO mapred.FileInputFormat: Total input files to process : 8
# 17/12/13 09:55:04 INFO mapreduce.JobSubmitter: number of splits:8
# 17/12/13 09:55:04 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_1513144645380_0013
# 17/12/13 09:55:04 INFO impl.YarnClientImpl: Submitted application application_1513144645380_0013
# 17/12/13 09:55:04 INFO mapreduce.Job: The url to track the job: http://8466be51a335:8088/proxy/application_1513144645380_0013/
# 17/12/13 09:55:04 INFO mapreduce.Job: Running job: job_1513144645380_0013
# 17/12/13 09:55:10 INFO mapreduce.Job: Job job_1513144645380_0013 running in uber mode : false
# 17/12/13 09:55:10 INFO mapreduce.Job:  map 0% reduce 0%
# 17/12/13 09:55:16 INFO mapreduce.Job:  map 75% reduce 0%
# 17/12/13 09:55:20 INFO mapreduce.Job:  map 100% reduce 0%
# 17/12/13 09:55:32 INFO mapreduce.Job:  map 100% reduce 79%
# 17/12/13 09:55:38 INFO mapreduce.Job:  map 100% reduce 86%
# 17/12/13 09:55:44 INFO mapreduce.Job:  map 100% reduce 93%
# 17/12/13 09:55:50 INFO mapreduce.Job:  map 100% reduce 100%
# 17/12/13 09:55:51 INFO mapreduce.Job: Job job_1513144645380_0013 completed successfully
# 17/12/13 09:55:51 INFO mapreduce.Job: Counters: 50
# 	File System Counters
# 		FILE: Number of bytes read=6833679
# 		FILE: Number of bytes written=14927372
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=5885986
# 		HDFS: Number of bytes written=11
# 		HDFS: Number of read operations=27
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of write operations=2
# 	Job Counters
# 		Killed map tasks=1
# 		Launched map tasks=8
# 		Launched reduce tasks=1
# 		Data-local map tasks=8
# 		Total time spent by all maps in occupied slots (ms)=28019
# 		Total time spent by all reduces in occupied slots (ms)=31820
# 		Total time spent by all map tasks (ms)=28019
# 		Total time spent by all reduce tasks (ms)=31820
# 		Total vcore-milliseconds taken by all map tasks=28019
# 		Total vcore-milliseconds taken by all reduce tasks=31820
# 		Total megabyte-milliseconds taken by all map tasks=28691456
# 		Total megabyte-milliseconds taken by all reduce tasks=32583680
# 	Map-Reduce Framework
# 		Map input records=474354
# 		Map output records=474354
# 		Map output bytes=5884955
# 		Map output materialized bytes=6833721
# 		Input split bytes=1040
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=474354
# 		Reduce shuffle bytes=6833721
# 		Reduce input records=474354
# 		Reduce output records=1
# 		Spilled Records=948708
# 		Shuffled Maps =8
# 		Failed Shuffles=0
# 		Merged Map outputs=8
# 		GC time elapsed (ms)=1127
# 		CPU time spent (ms)=39510
# 		Physical memory (bytes) snapshot=2569621504
# 		Virtual memory (bytes) snapshot=18095304704
# 		Total committed heap usage (bytes)=1758461952
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Input Format Counters
# 		Bytes Read=5884946
# 	File Output Format Counters
# 		Bytes Written=11
# 17/12/13 09:55:51 INFO streaming.StreamJob: Output directory: wordcount_result_1513158899132688
