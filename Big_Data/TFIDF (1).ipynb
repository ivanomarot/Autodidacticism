# %%
# %%writefile mapper1.py

import sys
import re

reload(sys)
sys.setdefaultencoding('utf-8') # required to convert to unicode

for line in sys.stdin:
    try:
        article_id, text = unicode(line.strip()).split('\t', 1)
    except ValueError as e:
        continue
    words = re.split("\W*\s+\W*", text, flags=re.UNICODE)
    if int(article_id) == 12:
        for word in words:
            print "%s\t%d" % (word.lower(), 1)
# Out:
# Writing mapper1.py

# %%
# %%writefile reducer1.py

import sys

current_key = None
word_sum = 0
N=0
Nt=0
tf=0

with open("stop_words_en.txt") as stopfile:
    stopwords = stopfile.readlines()
stopwords = list(map(lambda i:i.strip(),stopwords))
    
for line in sys.stdin:
    try:
        key, count = line.strip().split('\t', 1)
        count = int(count)
    except ValueError as e:
        continue
    if current_key != key:
        if current_key:
            if not(current_key in stopwords):
                #print "%s\t%d" % (current_key, word_sum)
                if current_key=="labor":
                    Nt=word_sum
                N=N+word_sum
            #print "%s\t%d" % (current_key, word_sum)
        word_sum = 0
        current_key = key
    word_sum += count

if current_key:
    #print "%s\t%d" % (current_key, word_sum)
    if current_key=="labor":
        Nt=word_sum
    N=N+word_sum
    tf=float(Nt)/float(N)
    print tf 
    #print Nt
    #print "tf=%d" %tf
# Out:
# Writing reducer1.py

# %%
# %%writefile combiner1.py

import sys

current_key = None
word_sum = 0
    
for line in sys.stdin:
    try:
        key, count = line.strip().split('\t', 1)
        count = int(count)
    except ValueError as e:
        continue
    if current_key != key:
        if current_key:
            print "%s\t%d" % (current_key, word_sum)
        word_sum = 0
        current_key = key
    word_sum += count

if current_key:
    print "%s\t%d" % (current_key, word_sum)
# Out:
# Writing combiner1.py

# %%
# %%writefile mapper2.py

import sys
import re
import math

reload(sys)
sys.setdefaultencoding('utf-8') # required to convert to unicode

Dt=0.0
idf=0.0
N=0.0

for line in sys.stdin:
    flag=0
    N=N+1
    try:
        article_id, text = unicode(line.strip()).split('\t', 1)
    except ValueError as e:
        continue
    words = re.split("\W*\s+\W*", text, flags=re.UNICODE)
    for word in words:
        #print "%s\t%d" % (word.lower(), 1)
        if word.lower()=="labor" and flag==0:
            Dt=Dt+1
            flag=1
idf=math.log(N/Dt)
print idf
# Out:
# Overwriting mapper2.py

# %%
# %%bash
#
# OUT_DIR="tf_result_"$(date +"%s%6N")
# NUM_REDUCERS=1
# OUT_DIR2="dt_result_"$(date +"%s%6N")
# NUM_REDUCERS2=1
#
# hdfs dfs -rm -r -skipTrash ${OUT_DIR} > /dev/null
#
# yarn jar /opt/cloudera/parcels/CDH/lib/hadoop-mapreduce/hadoop-streaming.jar \
#     -D mapred.jab.name="Term Count" \
#     -D mapreduce.job.reduces=${NUM_REDUCERS} \
#     -files mapper1.py,reducer1.py,combiner1.py,/datasets/stop_words_en.txt \
#     -mapper "python mapper1.py" \
#     -combiner "python combiner1.py" \
#     -reducer "python reducer1.py" \
#     -input /data/wiki/en_articles_part \
#     -output ${OUT_DIR} > /dev/null
#
# tf=$(hdfs dfs -cat ${OUT_DIR}/part-00000)
#
# hdfs dfs -rm -r -skipTrash ${OUT_DIR2} > /dev/null
#
# yarn jar /opt/cloudera/parcels/CDH/lib/hadoop-mapreduce/hadoop-streaming.jar \
#     -D mapred.jab.name="Doc Frequency" \
#     -files mapper2.py \
#     -mapper "python mapper2.py" \
#     -numReduceTasks 0 \
#     -input /data/wiki/en_articles_part \
#     -output ${OUT_DIR2} > /dev/null
#
# idf=$(hdfs dfs -cat ${OUT_DIR2}/part-00000)
#
# tfidf=$(echo "${tf}*${idf}" |bc)
#
# printf '%.10f\n' ${tfidf}
# Out:
# 0.0053071615
# rm: `tf_result_1515693724648636': No such file or directory
# 18/01/11 18:02:08 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 18/01/11 18:02:08 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 18/01/11 18:02:08 INFO mapred.FileInputFormat: Total input files to process : 1
# 18/01/11 18:02:08 INFO mapreduce.JobSubmitter: number of splits:2
# 18/01/11 18:02:08 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_1515627025943_0026
# 18/01/11 18:02:09 INFO impl.YarnClientImpl: Submitted application application_1515627025943_0026
# 18/01/11 18:02:09 INFO mapreduce.Job: The url to track the job: http://9de2cfc801c0:8088/proxy/application_1515627025943_0026/
# 18/01/11 18:02:09 INFO mapreduce.Job: Running job: job_1515627025943_0026
# 18/01/11 18:02:15 INFO mapreduce.Job: Job job_1515627025943_0026 running in uber mode : false
# 18/01/11 18:02:15 INFO mapreduce.Job:  map 0% reduce 0%
# 18/01/11 18:02:24 INFO mapreduce.Job:  map 100% reduce 0%
# 18/01/11 18:02:29 INFO mapreduce.Job:  map 100% reduce 100%
# 18/01/11 18:02:29 INFO mapreduce.Job: Job job_1515627025943_0026 completed successfully
# 18/01/11 18:02:29 INFO mapreduce.Job: Counters: 49
# 	File System Counters
# 		FILE: Number of bytes read=37453
# 		FILE: Number of bytes written=496597
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=76874501
# 		HDFS: Number of bytes written=18
# 		HDFS: Number of read operations=9
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of write operations=2
# 	Job Counters
# 		Launched map tasks=2
# 		Launched reduce tasks=1
# 		Data-local map tasks=2
# 		Total time spent by all maps in occupied slots (ms)=12614
# 		Total time spent by all reduces in occupied slots (ms)=2381
# 		Total time spent by all map tasks (ms)=12614
# 		Total time spent by all reduce tasks (ms)=2381
# 		Total vcore-milliseconds taken by all map tasks=12614
# 		Total vcore-milliseconds taken by all reduce tasks=2381
# 		Total megabyte-milliseconds taken by all map tasks=12916736
# 		Total megabyte-milliseconds taken by all reduce tasks=2438144
# 	Map-Reduce Framework
# 		Map input records=4100
# 		Map output records=10309
# 		Map output bytes=90282
# 		Map output materialized bytes=37459
# 		Input split bytes=228
# 		Combine input records=10309
# 		Combine output records=2953
# 		Reduce input groups=2953
# 		Reduce shuffle bytes=37459
# 		Reduce input records=2953
# 		Reduce output records=1
# 		Spilled Records=5906
# 		Shuffled Maps =2
# 		Failed Shuffles=0
# 		Merged Map outputs=2
# 		GC time elapsed (ms)=186
# 		CPU time spent (ms)=4030
# 		Physical memory (bytes) snapshot=800112640
# 		Virtual memory (bytes) snapshot=6037110784
# 		Total committed heap usage (bytes)=553648128
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Input Format Counters
# 		Bytes Read=76874273
# 	File Output Format Counters
# 		Bytes Written=18
# 18/01/11 18:02:29 INFO streaming.StreamJob: Output directory: tf_result_1515693724648636
# rm: `dt_result_1515693724649772': No such file or directory
# 18/01/11 18:02:35 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 18/01/11 18:02:35 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 18/01/11 18:02:35 INFO mapred.FileInputFormat: Total input files to process : 1
# 18/01/11 18:02:35 INFO mapreduce.JobSubmitter: number of splits:2
# 18/01/11 18:02:36 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_1515627025943_0027
# 18/01/11 18:02:36 INFO impl.YarnClientImpl: Submitted application application_1515627025943_0027
# 18/01/11 18:02:36 INFO mapreduce.Job: The url to track the job: http://9de2cfc801c0:8088/proxy/application_1515627025943_0027/
# 18/01/11 18:02:36 INFO mapreduce.Job: Running job: job_1515627025943_0027
# 18/01/11 18:02:42 INFO mapreduce.Job: Job job_1515627025943_0027 running in uber mode : false
# 18/01/11 18:02:42 INFO mapreduce.Job:  map 0% reduce 0%
# 18/01/11 18:02:52 INFO mapreduce.Job:  map 100% reduce 0%
# 18/01/11 18:02:52 INFO mapreduce.Job: Job job_1515627025943_0027 completed successfully
# 18/01/11 18:02:52 INFO mapreduce.Job: Counters: 30
# 	File System Counters
# 		FILE: Number of bytes read=0
# 		FILE: Number of bytes written=278026
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=76874501
# 		HDFS: Number of bytes written=30
# 		HDFS: Number of read operations=10
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of write operations=4
# 	Job Counters
# 		Launched map tasks=2
# 		Data-local map tasks=2
# 		Total time spent by all maps in occupied slots (ms)=15882
# 		Total time spent by all reduces in occupied slots (ms)=0
# 		Total time spent by all map tasks (ms)=15882
# 		Total vcore-milliseconds taken by all map tasks=15882
# 		Total megabyte-milliseconds taken by all map tasks=16263168
# 	Map-Reduce Framework
# 		Map input records=4100
# 		Map output records=2
# 		Input split bytes=228
# 		Spilled Records=0
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=113
# 		CPU time spent (ms)=1990
# 		Physical memory (bytes) snapshot=369086464
# 		Virtual memory (bytes) snapshot=4019318784
# 		Total committed heap usage (bytes)=303562752
# 	File Input Format Counters
# 		Bytes Read=76874273
# 	File Output Format Counters
# 		Bytes Written=30
# 18/01/11 18:02:52 INFO streaming.StreamJob: Output directory: dt_result_1515693724649772
