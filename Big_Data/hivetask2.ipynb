# %%
# %%writefile query.hql
#
# ADD JAR /opt/cloudera/parcels/CDH/lib/hive/lib/hive-contrib.jar;
# ADD JAR /opt/cloudera/parcels/CDH/lib/hive/lib/hive-serde.jar;
#
# USE stackoverflow_;
#
# WITH
# TAG_EX_2016 AS (
#     SELECT post_type_id,tag
#     FROM stackoverflow_.posts LATERAL VIEW explode(tags) tagTable AS tag
#     WHERE Year=2016 and tags IS NOT NULL
# ),
# TAG_EX_2009 AS (
#     SELECT post_type_id,tag
#     FROM stackoverflow_.posts LATERAL VIEW explode(tags) tagTable AS tag
#     WHERE Year=2009 and tags IS NOT NULL
# ),
# TAG_COUNT_2016 AS (
#     SELECT tag, COUNT(post_type_id) AS id_count_2016
#     FROM TAG_EX_2016
#     GROUP BY tag
# ),
# TAG_COUNT_2009 AS (
#     SELECT tag, COUNT(post_type_id) AS id_count_2009
#     FROM TAG_EX_2009
#     GROUP BY tag
# ),
# TAG_RANKED_2016 AS (
#     SELECT tag AS tag_2016, id_count_2016, RANK() OVER(ORDER BY id_count_2016 DESC) AS tag_rank_2016
#     FROM TAG_COUNT_2016
# ),
# TAG_RANKED_2009 AS (
#     SELECT tag AS tag_2009, id_count_2009, RANK() OVER(ORDER BY id_count_2009 DESC) AS tag_rank_2009
#     FROM TAG_COUNT_2009
# )
# SELECT tag_2016,tag_rank_2016,tag_rank_2009,id_count_2016,id_count_2009
# FROM TAG_RANKED_2016,TAG_RANKED_2009
# WHERE tag_2016=tag_2009
# ORDER BY tag_rank_2016
# LIMIT 10
# Out:
# Writing query.hql

# %%
! hive -f query.hql
# Out:
# Logging initialized using configuration in jar:file:/usr/local/apache-hive-1.1.0-bin/lib/hive-common-1.1.0.jar!/hive-log4j.properties
# Added [/opt/cloudera/parcels/CDH/lib/hive/lib/hive-contrib.jar] to class path
# Added resources: [/opt/cloudera/parcels/CDH/lib/hive/lib/hive-contrib.jar]
# Added [/opt/cloudera/parcels/CDH/lib/hive/lib/hive-serde.jar] to class path
# Added resources: [/opt/cloudera/parcels/CDH/lib/hive/lib/hive-serde.jar]
# OK
# Time taken: 1.151 seconds
# Query ID = jovyan_20180311030101_03d40da1-3b5b-4a0e-800f-e0d6d4bdf9e8
# Total jobs = 8
# Launching Job 1 out of 8
# Number of reduce tasks not specified. Estimated from input data size: 1
# In order to change the average load for a reducer (in bytes):
#   set hive.exec.reducers.bytes.per.reducer=<number>
# In order to limit the maximum number of reducers:
#   set hive.exec.reducers.max=<number>
# In order to set a constant number of reducers:
#   set mapreduce.job.reduces=<number>
# Starting Job = job_1520347510338_0004, Tracking URL = http://0f37f817f6c6:8088/proxy/application_1520347510338_0004/
# Kill Command = /opt/hadoop/bin/hadoop job  -kill job_1520347510338_0004
# Hadoop job information for Stage-1: number of mappers: 1; number of reducers: 1
# 2018-03-11 03:02:00,763 Stage-1 map = 0%,  reduce = 0%
# 2018-03-11 03:02:14,927 Stage-1 map = 100%,  reduce = 0%, Cumulative CPU 8.19 sec
# 2018-03-11 03:02:27,558 Stage-1 map = 100%,  reduce = 100%, Cumulative CPU 14.14 sec
# MapReduce Total cumulative CPU time: 14 seconds 140 msec
# Ended Job = job_1520347510338_0004
# Launching Job 2 out of 8
# Number of reduce tasks not specified. Estimated from input data size: 1
# In order to change the average load for a reducer (in bytes):
#   set hive.exec.reducers.bytes.per.reducer=<number>
# In order to limit the maximum number of reducers:
#   set hive.exec.reducers.max=<number>
# In order to set a constant number of reducers:
#   set mapreduce.job.reduces=<number>
# Starting Job = job_1520347510338_0005, Tracking URL = http://0f37f817f6c6:8088/proxy/application_1520347510338_0005/
# Kill Command = /opt/hadoop/bin/hadoop job  -kill job_1520347510338_0005
# Hadoop job information for Stage-5: number of mappers: 1; number of reducers: 1
# 2018-03-11 03:02:50,057 Stage-5 map = 0%,  reduce = 0%
# 2018-03-11 03:03:02,614 Stage-5 map = 100%,  reduce = 0%, Cumulative CPU 6.64 sec
# 2018-03-11 03:03:16,065 Stage-5 map = 100%,  reduce = 100%, Cumulative CPU 12.06 sec
# MapReduce Total cumulative CPU time: 12 seconds 60 msec
# Ended Job = job_1520347510338_0005
# Launching Job 3 out of 8
# Number of reduce tasks not specified. Estimated from input data size: 1
# In order to change the average load for a reducer (in bytes):
#   set hive.exec.reducers.bytes.per.reducer=<number>
# In order to limit the maximum number of reducers:
#   set hive.exec.reducers.max=<number>
# In order to set a constant number of reducers:
#   set mapreduce.job.reduces=<number>
# Starting Job = job_1520347510338_0006, Tracking URL = http://0f37f817f6c6:8088/proxy/application_1520347510338_0006/
# Kill Command = /opt/hadoop/bin/hadoop job  -kill job_1520347510338_0006
# Hadoop job information for Stage-2: number of mappers: 1; number of reducers: 1
# 2018-03-11 03:03:38,424 Stage-2 map = 0%,  reduce = 0%
# 2018-03-11 03:03:50,563 Stage-2 map = 100%,  reduce = 0%, Cumulative CPU 3.98 sec
# 2018-03-11 03:04:03,827 Stage-2 map = 100%,  reduce = 100%, Cumulative CPU 10.76 sec
# MapReduce Total cumulative CPU time: 10 seconds 760 msec
# Ended Job = job_1520347510338_0006
# Launching Job 4 out of 8
# Number of reduce tasks not specified. Estimated from input data size: 1
# In order to change the average load for a reducer (in bytes):
#   set hive.exec.reducers.bytes.per.reducer=<number>
# In order to limit the maximum number of reducers:
#   set hive.exec.reducers.max=<number>
# In order to set a constant number of reducers:
#   set mapreduce.job.reduces=<number>
# Starting Job = job_1520347510338_0007, Tracking URL = http://0f37f817f6c6:8088/proxy/application_1520347510338_0007/
# Kill Command = /opt/hadoop/bin/hadoop job  -kill job_1520347510338_0007
# Hadoop job information for Stage-6: number of mappers: 1; number of reducers: 1
# 2018-03-11 03:04:26,369 Stage-6 map = 0%,  reduce = 0%
# 2018-03-11 03:04:37,775 Stage-6 map = 100%,  reduce = 0%, Cumulative CPU 3.0 sec
# 2018-03-11 03:04:48,607 Stage-6 map = 100%,  reduce = 100%, Cumulative CPU 9.14 sec
# MapReduce Total cumulative CPU time: 9 seconds 140 msec
# Ended Job = job_1520347510338_0007
# Stage-10 is selected by condition resolver.
# Stage-11 is filtered out by condition resolver.
# Stage-3 is filtered out by condition resolver.
# Execution log at: /tmp/jovyan/jovyan_20180311030101_03d40da1-3b5b-4a0e-800f-e0d6d4bdf9e8.log
# 2018-03-11 03:04:58	Starting to launch local task to process map join;	maximum memory = 477626368
# 2018-03-11 03:05:00	Dump the side-table for tag: 1 with group count: 2369 into file: file:/tmp/jovyan/42809068-c8ad-4854-8995-3bcc9671ea68/hive_2018-03-11_03-01-31_323_5891867705969390852-1/-local-10008/HashTable-Stage-7/MapJoin-mapfile01--.hashtable
# 2018-03-11 03:05:00	Uploaded 1 File to: file:/tmp/jovyan/42809068-c8ad-4854-8995-3bcc9671ea68/hive_2018-03-11_03-01-31_323_5891867705969390852-1/-local-10008/HashTable-Stage-7/MapJoin-mapfile01--.hashtable (76823 bytes)
# 2018-03-11 03:05:00	End of local task; Time Taken: 1.895 sec.
# Execution completed successfully
# MapredLocal task succeeded
# Launching Job 6 out of 8
# Number of reduce tasks is set to 0 since there's no reduce operator
# Starting Job = job_1520347510338_0008, Tracking URL = http://0f37f817f6c6:8088/proxy/application_1520347510338_0008/
# Kill Command = /opt/hadoop/bin/hadoop job  -kill job_1520347510338_0008
# Hadoop job information for Stage-7: number of mappers: 1; number of reducers: 0
# 2018-03-11 03:05:17,263 Stage-7 map = 0%,  reduce = 0%
# 2018-03-11 03:05:28,887 Stage-7 map = 100%,  reduce = 0%, Cumulative CPU 6.53 sec
# MapReduce Total cumulative CPU time: 6 seconds 530 msec
# Ended Job = job_1520347510338_0008
# Launching Job 7 out of 8
# Number of reduce tasks determined at compile time: 1
# In order to change the average load for a reducer (in bytes):
#   set hive.exec.reducers.bytes.per.reducer=<number>
# In order to limit the maximum number of reducers:
#   set hive.exec.reducers.max=<number>
# In order to set a constant number of reducers:
#   set mapreduce.job.reduces=<number>
# Starting Job = job_1520347510338_0009, Tracking URL = http://0f37f817f6c6:8088/proxy/application_1520347510338_0009/
# Kill Command = /opt/hadoop/bin/hadoop job  -kill job_1520347510338_0009
# Hadoop job information for Stage-4: number of mappers: 1; number of reducers: 1
# 2018-03-11 03:05:49,292 Stage-4 map = 0%,  reduce = 0%
# 2018-03-11 03:06:00,290 Stage-4 map = 100%,  reduce = 0%, Cumulative CPU 3.63 sec
# 2018-03-11 03:06:10,417 Stage-4 map = 100%,  reduce = 100%, Cumulative CPU 7.29 sec
# MapReduce Total cumulative CPU time: 7 seconds 290 msec
# Ended Job = job_1520347510338_0009
# MapReduce Jobs Launched:
# Stage-Stage-1: Map: 1  Reduce: 1   Cumulative CPU: 14.14 sec   HDFS Read: 834998 HDFS Write: 283234 SUCCESS
# Stage-Stage-5: Map: 1  Reduce: 1   Cumulative CPU: 12.06 sec   HDFS Read: 145118 HDFS Write: 67863 SUCCESS
# Stage-Stage-2: Map: 1  Reduce: 1   Cumulative CPU: 10.76 sec   HDFS Read: 289366 HDFS Write: 311766 SUCCESS
# Stage-Stage-6: Map: 1  Reduce: 1   Cumulative CPU: 9.14 sec   HDFS Read: 73995 HDFS Write: 74637 SUCCESS
# Stage-Stage-7: Map: 1   Cumulative CPU: 6.53 sec   HDFS Read: 316612 HDFS Write: 55844 SUCCESS
# Stage-Stage-4: Map: 1  Reduce: 1   Cumulative CPU: 7.29 sec   HDFS Read: 61032 HDFS Write: 188 SUCCESS
# Total MapReduce CPU Time Spent: 59 seconds 920 msec
# OK
# javascript	1	5	2771	192
# java	2	2	2033	243
# android	3	52	1809	25
# php	4	3	1673	215
# python	5	11	1585	108
# c#	6	1	1519	423
# html	7	14	1212	84
# jquery	8	8	1167	141
# ios	9	186	914	7
# css	10	20	801	59
# Time taken: 282.412 seconds, Fetched: 10 row(s)
